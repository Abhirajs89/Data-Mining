# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r-')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
plt.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axex.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.4,0.3,0.3])
axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title('First')

axes[1].plot(y,x)
axes[1].set_title('Second')

plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1, figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig.savefig('myfig.png',dpi=100)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared',color='purple',linewidth='2',alpha=0.5,marker='o',markersize=5,markerfacecolor='green') #RGB hexcode
ax.plot(x,x**3,label='X Cubed',color='red',linestyle='--',marker='*')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared',color='purple',linewidth='2',alpha=0.5,marker='o',markersize=5,markerfacecolor='green') #RGB hexcode
ax.plot(x,x**3,label='X Cubed',color='red',linestyle='--',marker='*')
ax.set_xlim([0,3])
ax.set_ylim([0,15])
ax.legend(loc=0)
